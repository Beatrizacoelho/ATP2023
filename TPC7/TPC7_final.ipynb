# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
resPol =[]
def criaPol():
    polinomios = int(input("Quantos poliómios quer fazer?"))
    while polinomios > 0:
        resMon = []
        termo = int(input("Quantos termos tem o polinónio?"))
        while termo > 0:
            coeficiente = float(input("Qual é o coeficiente?"))
            expoente = int(input("Qual é o expoente?"))
            termo = termo - 1
            if coeficiente !=0:
                resMon.append((coeficiente,expoente))
        resPol.append(resMon)
        polinomios = polinomios - 1
    print(resPol)
    return resPol

def guardaPol(fnome):
    fpol = open(fnome, "w")
    for pol in resPol:
        for monomio in pol:
            coeficiente,expoente = monomio
            fpol.write (str(coeficiente) + ", " + str(expoente) + " |")
        fpol.write("\n")
    fpol.close
    return

def lerPol(fnome):
    res = []
    fpol = open(fnome)
    for linha in fpol:
        pol = []
        termos = linha.split ("|")
        termos.remove ("\n")
        for t in termos:
            monomio = t.split (",")
            pol.append((float(monomio[0]), int(nomomio[1])))
        res.append(pol)
    fpol.close()
    return res

def listarPol(fnome):
    n = 1
    fpol = open(fnome)
    print("ordem || monomio")
    print("-------------------------------------------")
    for linha in fpol:
        pol = ()
        termos = linha.split("|")
        termos.remove("\n")
        res = ""
        for t in termos:
            monomio = t.split(",")
            coeficiente, expoente = monomio
            if float(coeficiente) < 0:
                res = (f"{res}{str(coeficiente)}")
            else:
                res = (f"{res}+{str(coeficiente)}")
            if float(coeficiente) != 0:
                if expoente != 0:
                    res = (f"{res}x^{str(expoente)}")
                    pol = (res)
        print(f"  {n}  ||  {pol}  ")
        n = n + 1
        print("--------------------------------------------------")
    fpol.close()

def calcPol(p,x):
    res = 0
    for termo in p:
        coeficiente, expoente = termo
        res = res + (x**expoente)*coeficiente
    return res

def listarPolGrau(fnome):
    n = 1
    fpol = open(fnome)
    print ("ordem || grau || monomio")
    print ("------------------------------------------------")
    for linha in fpol:
        pol = ()
        termos = linha.split("|")
        termos.remove("\n")
        res = ""
        maior = 0
        for t in termos:
            monomio = t.split(",")
            coeficiente, expoente = monomio
            if float(coeficiente) < 0:
                res = (f"{res}{str(coeficiente)}")
            else:
                res = (f"{res}+{str(coeficiente)}")
            if float(coeficiente) != 0:
                if expoente != 0:
                    res = (f"{res}x^{str(expoente)}")
                    pol = (res)
            if int(expoente) >int(maior):
                maior = expoente
        print(f"  {n}  ||  {maior}  ||  {pol}  ")
        n = n + 1
        print("--------------------------------------------------")
    fpol.close()

def grauPol(fnome):
    maior = 0
    ordem = 0
    a = ()
    n = 1
    fpol = open(fnome)
    for linha in fpol:
        pol = ()
        termos = linha.split("|")
        termos.remove("\n")
        res = ""
        ordem = ordem + 1
        for t in termos:
            monomio = t.split(",")
            coeficiente, expoente =  monomio
            if int(expoente) >int(maior):
                maior = expoente
                a = (maior, ordem)
    print(a)

def derivada(fnome):
    fpol = open(fnome)
    print ("polinomio || derivada")
    print ("-----------------------------------------")
    for linha in pol:
        poli = []
        termos = linha.split("|")
        termos.remove("\n")
        for t in termos:
            monomio = t.split(",")
            poli.append((float(monomio[0]), int(nomomio[1])))
            res = ""
            derivada = []
            for n in poli:
                coeficiente, expoente = n
                if float(coeficiente) < 0:
                    res = (f"{res}{str(coeficiente)}")
                else:
                    res = (f"{res}+{str(coeficiente)}")
                if float(coeficiente) != 0:
                    if expoente != 0:
                        res = (f"{res}x^{str(expoente)}")

                coeficiente = coeficiente * expoente
                expoente = expoente - 1
                derivada.append((coeficente,expoente))
                resd = ""
                for d in derivada:
                    coeficiented, expoented = d
                    if float(coeficiente) < 0:
                        res = (f"{res}{str(coeficiente)}")
                    else:
                        res = (f"{res}+{str(coeficiente)}")
                    if float(coeficiente) != 0:
                        if expoente != 0:
                            res = (f"{res}x^{str(expoente)}")
        print (f"{res}  || {resd}")
        print ("--------------------------------------------------------")

def somaPol(pol1, pol2):
    coeficienteres = 0
    expoenteres = 0
    npol =()
    soa = []
    for coeficiente1, expoente1 in pol1:
        encontrado = False
        for coeficiente2, expoente2 in pol2:
            if expoente1 == expoente2:
                coeficienteres= coeficiente1 + coeficiente2
                npol = (coeficienteres, expoente1)
                somaPol.append(npol)
                encontrado = True
        if encontrado == False:
            npol = (coeficiente1, expoente1)
            somaPol.append(npol)
    for coeficiente2, expoente2 in pol2:
        encontrado = False
        for coeficiente1, expoente1 in pol1:
            if expoente1 == expoente2:
                encontrado = True
        if encontrado == False:
            npol = (coeficiente2, expoente2)
            somaPol.append(npol)
    
    x=sorted (somaPol, reverse = True, Key = lambda x: x[1])
    res = ""
    for n in x:
        coeficiente, expoente = n
        if float(coeficiente) < 0:
            res = (f"{res}{str(coeficiente)}")
        else:
            res = (f"{res}+{str(coeficiente)}")
        if float(coeficiente) != 0:
            if expoente != 0:
                res = (f"{res}x^{str(expoente)}")
    print(res)

def desenharGrafico(p):
    import matplotlib.pyplot as plt
    import numpy as np
    coef = []
    for monomio in p:
        coeficiente, expoente = monomio
        coef.append(coeficientes)
    x = np.linspace(-10, 10, 400)
    y = sum(coeficiente * x ** expoente for expoente, coeficiente in enumerate(coef))

    plt.plot(x,y, label=f"polinomio: {p}")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Gráfico de um polinómio")
    plt.grid(True)
    plt.legend()
    plt.show()

def menu():
    print("""1. Criar um polinómio;
    2. Ler lista de polinómios;
    3. Listar polinómios;
    4. Calcular o valor de um polinómio num ponto;
    5. Listar polinómios com grau;
    6. Maior grau;
    7. Derivada;
    8. Somar dois polinómios;
    9. Gerar um gráfico para o polinómio;
    10. Gravar num ficheiro os polinómios em memória;
    0. Sair da aplicação""")

escolha = -1
print(menu())
while escolha != 0:
    escolha = int(input("Selecione a opção que quer"))
    if escolha == 1:
        criaPolIn()
    if escolha == 2:
        print(lerPolinomios("polinomios2.txt"))
    if escolha == 3:
        listarPolinomios("polinomios2.txt")
    if escolha== 4:
        p = int(input("Qual a ordem do polinómio que quer?"))
        x = int(input("Qual é o valor de x que quer?"))
        print(calcPolinomio(lerPolinomios("polinomios2.txt")[(p-1)], x))
    if escolha == 5:
        listarPolinomiosGrau("polinomios2.txt")
    if escolha == 6:
        grauPolinomios("polinomios2.txt")
    if escolha == 7:
        derivada("polinomios2.txt")
    if escolha == 8:
       pol1 = int(input("Qual é o primeiro polinómio?"))
       pol2 = int(input("Qual é o outro polinómio?"))
       soma(calcPolinomio(lerPolinomios("polinomios2.txt")[(pol1-1)], calcPolinomio(lerPolinomios("polinomios2.txt")[(pol2-1)])))
    if escolha == 9:
       p = int(input("Qual a ordem do polinómio que quer?"))
       desenhaGráfico(lerPolinomios("polinomios2.txt")[(p-1)]) 
    if escolha == 10:
        guardarPolinomios("polinomios2.txt")
# Out:
# 1. Criar um polinómio;
#     2. Ler lista de polinómios;
#     3. Listar polinómios;
#     4. Calcular o valor de um polinómio num ponto;
#     5. Listar polinómios com grau;
#     6. Maior grau;
#     7. Derivada;
#     8. Somar dois polinómios;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\beatr\Desktop\TPC7\TPC7_final.ipynb Cell 2 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/beatr/Desktop/TPC7/TPC7_final.ipynb#W1sZmlsZQ%3D%3D?line=232'>233</a> print(menu())
#     <a href='vscode-notebook-cell:/c%3A/Users/beatr/Desktop/TPC7/TPC7_final.ipynb#W1sZmlsZQ%3D%3D?line=233'>234</a> while escolha != 0:
# --> <a href='vscode-notebook-cell:/c%3A/Users/beatr/Desktop/TPC7/TPC7_final.ipynb#W1sZmlsZQ%3D%3D?line=234'>235</a>     escolha = int(input("Selecione a opção que quer"))
#     <a href='vscode-notebook-cell:/c%3A/Users/beatr/Desktop/TPC7/TPC7_final.ipynb#W1sZmlsZQ%3D%3D?line=235'>236</a>     if escolha == 1:
#     <a href='vscode-notebook-cell:/c%3A/Users/beatr/Desktop/TPC7/TPC7_final.ipynb#W1sZmlsZQ%3D%3D?line=236'>237</a>         criaPolIn()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
